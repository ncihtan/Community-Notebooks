# %% [markdown]
# <a href="https://colab.research.google.com/github/isb-cgc/Community-Notebooks/blob/master/HTAN/Python%20Notebooks/A_Guide_to_HTAN_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Guide to HTAN Data

# %% [markdown]
#         Title:   A Guide to HTAN Data
#         Author:  Clarisse Lau
#         Created: 2024-05-13
#         Updated: 2025-06-06
#         Purpose: Provide an overview of HTAN data types and volumes

# %% [markdown]
# # 1. Introduction & Overview
# The Human Tumor Atlas Network ([HTAN](https://humantumoratlas.org/)) is a National Cancer Institute (NCI)-funded Cancer Moonshot<sup>SM</sup> initiative to construct 3-dimensional atlases of the dynamic cellular, morphological, and molecular features of human cancers as they evolve from precancerous lesions to advanced disease [[Cell April 2020](https://www.sciencedirect.com/science/article/pii/S0092867420303469)]
#
#
# ### 1.1 Goal
#
# This notebook aims to provide an overview of the data accessible within HTAN, presenting at-a-glance summaries, specific statistics such as total cell counts, as well as example queries and attributes that can be used to filter for data of interest. The findings presented reflect the status of HTAN Data Release 5.1.
#
# ### 1.2 Inputs, Outputs, & Data
# The originating data can be found on the [HTAN Data Portal](https://humantumoratlas.org/), and the compiled tables are on the [ISB-Cancer Gateway in the Cloud](https://isb-cgc.appspot.com/bq_meta_search/).
#
# Each query output loads to a Data Table, an interactive display of resulting columns and rows. You are able to select the link below the table to review the [Data Table Notebook](https://colab.research.google.com/notebooks/data_table.ipynb) that gives tips on filtering and further customizing the table.
#
# ### 1.3 Notes
# The queries and results in this notebook correspond to ISB-CGC's most current HTAN Release.
#
# To choose a specific release, edit the BigQuery table names in this notebook by replacing the relevant string endings:
# - `current` with a selected numbered release, e.g., `r2`
# - `HTAN` with `HTAN_versioned`
# - `gc` with `cds` (if applicable)
#
# #
# ### ⚠️PAUSE
# Notebooks associated with ISB-CGC HTAN Releases 6.0 or earlier are based on the **HTAN Phase 1 Data Model**. Please be aware that the structure, terminology, and available data elements may differ from those in Phase 2.

# %% [markdown]
# # 2. Environment & Module Setup

# %%
# import libraries
import pandas as pd

# %% [markdown]
# Enable interactive table formatting:

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
from google.colab.data_table import DataTable
DataTable.max_columns = 30

# %% [markdown]
# # 3. Google Authentication
#
# Running the BigQuery cells in this notebook requires a Google Cloud Project. Instructions for creating a project can be found in [Google Cloud Documentation](https://cloud.google.com/resource-manager/docs/creating-managing-projects#console). The instance needs to be authorized to bill the project for queries. For more information on getting started with ISB-CGC see [Quick Start Guide to ISB-CGC](https://isb-cancer-genomics-cloud.readthedocs.io/en/latest/sections/HowToGetStartedonISB-CGC.html) and alternative authentication methods can be found in [Google Cloud Authentication Documentation](https://cloud.google.com/docs/authentication).

# %% [markdown]
# ## 3.1 Authenticating with Google Credentials

# %% [markdown]
# #### Option 1. Running in Google Colab
#
# If you are using Google Colab, run the code block below to authenticate

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# #### Option 2. Running on local machine
#
# Alternatively, if you're running the notebook locally, take the following steps to authenticate.
#
# 1.   Run `gcloud auth application-default login` on your local machine
# 2.   Run the command below replacing `<path to key>` with the path to your credentials file

# %%
# env GOOGLE_APPLICATION_CREDENTIALS='<path to key>'

# %% [markdown]
# ## 3.2 Initializing the Google BigQuery client

# %%
# Import the Google BigQuery client
from google.cloud import bigquery

# Set the Google project that will be billed for this notebook's computations
# Replace <my-project> with your BigQuery Project ID
google_project = '<my-project>'

# Create a client to access the data within BigQuery
client = bigquery.Client(google_project)

# %% [markdown]
# # 4. Summary of Data in HTAN

# %% [markdown]
# ## 4.1 Data Levels by Center
#
# In the query below, a data file listing is first obtained using the ID Provenance table (see the [HTAN_ID_Provenance_In_BQ.ipynb](https://github.com/isb-cgc/Community-Notebooks/blob/master/HTAN/Python%20Notebooks/HTAN_ID_Provenance_In_BQ.ipynb) notebook for a tutorial on using the ID Provenance table).
#
# HTAN imaging metadata annotations differ slightly from other assay types, as they encompass multiple imaging and spatial modalities. For example, H&E, MIBI, CODEX, etc. types are all annotated under the imaging template. In order to distinguish these assay types in our summary, we utilize the `Imaging Assay Type` attribute. As `Imaging Assay Type` is exclusively found in the `ImagingLevel2` table, we conduct a sequence of joins utilizing the parent data file lineage to classify higher-level imaging data by assay type.
#
# In the next portions of the query we split the component name e.g. `ScRNA-seqLevel2` into separate assay type (`ScRNA-seq`)and data level (`Level2`) attributes.
#
# Lastly, we group by assay type, data level, and HTAN center, and pivot the table to provide a concise overview of all HTAN data types by center, along with the levels available.

# %%
summary = client.query("""
  WITH prov AS (
    SELECT DISTINCT HTAN_Data_File_ID, entityId, Component, HTAN_Center
    FROM `isb-cgc-bq.HTAN.id_provenance_current`
    WHERE Component IS NOT NULL
    AND Component NOT LIKE '%Auxiliary%'
    AND Component NOT LIKE 'OtherAssay'
  ),
  img AS(SELECT * EXCEPT(HTAN_Data_File_ID) FROM (
    SELECT HTAN_Data_File_ID,Imaging_Assay_Type,entityId
    FROM `isb-cgc-bq.HTAN.imaging_level2_metadata_current`
    WHERE Component IS NOT NULL
    UNION ALL
    SELECT il3s.HTAN_Data_File_ID,il2.Imaging_Assay_Type,il3s.entityId
    FROM `isb-cgc-bq.HTAN.imaging_level2_metadata_current` il2
    JOIN (SELECT * FROM `isb-cgc-bq.HTAN.id_provenance_current`
      WHERE Component = 'ImagingLevel3Segmentation') il3s
    ON il2.HTAN_Data_File_ID = il3s.HTAN_Parent_Data_File_ID
    UNION ALL
    SELECT il4.HTAN_Data_File_ID,il2.Imaging_Assay_Type,il4.entityId
    FROM `isb-cgc-bq.HTAN.imaging_level2_metadata_current` il2
    JOIN (SELECT * FROM `isb-cgc-bq.HTAN.id_provenance_current`
      WHERE Component = 'ImagingLevel3Segmentation') il3s
    ON il2.HTAN_Data_File_ID = il3s.HTAN_Parent_Data_File_ID
    JOIN (SELECT * FROM `isb-cgc-bq.HTAN.id_provenance_current`
      WHERE Component = 'ImagingLevel4') il4
    ON il3s.HTAN_Data_File_ID = il4.HTAN_Parent_Data_File_ID
  )
  ),
  files AS (
    SELECT HTAN_Center,array_to_string([SPLIT(Component, 'Level')[OFFSET(0)], Imaging_Assay_Type], ' - ') AS Assay,
    REGEXP_EXTRACT(Component, r'Level\d') AS Level
    FROM prov
    LEFT JOIN img USING(entityId)
    GROUP BY HTAN_Center, Assay, Level
    ORDER BY HTAN_Center, Assay, Level
  )
  SELECT HTAN_Center, Assay, STRING_AGG(DISTINCT Level ORDER BY Level) AS Levels
  FROM files
  GROUP BY HTAN_Center, Assay
""").result().to_dataframe()

# %%
summary.pivot(index='Assay', columns='HTAN_Center', values='Levels').fillna('')
# Out:
# HTAN_Center                                                   HTAN BU  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq                                      Level1,Level2,Level3
# BulkWES                                          Level1,Level2,Level3
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                                  Level2
# Imaging - IMC                                                  Level2
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq
#
# HTAN_Center                                                 HTAN CHOP  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES                                          Level1,Level2,Level3
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX                                  Level2,Level3,Level4
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq                                Level1,Level2,Level3,Level4
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq
#
# HTAN_Center                                          HTAN DFCI  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES                                                 Level2
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH                                       Level2
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3
# Slide-seq
#
# HTAN_Center                                                 HTAN Duke  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq                                      Level1,Level2,Level3
# BulkWES                                          Level1,Level2,Level3
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging                                                        Level4
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                                  Level2
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI                                          Level2,Level3
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq
#
# HTAN_Center                                           HTAN HMS  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq                               Level1,Level2,Level3
# BulkWES
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                           Level2
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion                  Level2,Level3,Level4
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF                         Level2,Level3,Level4
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq
# Slide-seq
#
# HTAN_Center                                                HTAN HTAPP  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq          Level1,Level2,Level3
# BulkMethylation-seq
# BulkRNA-seq                                                    Level2
# BulkWES                                                        Level2
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging                                                        Level4
# Imaging - CODEX                                                Level2
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                                  Level2
# Imaging - IMC
# Imaging - MERFISH                                Level2,Level3,Level4
# Imaging - MIBI                                   Level2,Level3,Level4
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq                                        Level1,Level2,Level3
#
# HTAN_Center                                                  HTAN MSK  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging                                                        Level4
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI                                                 Level2
# Imaging - MxIF                                                 Level2
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq
#
# HTAN_Center                                          HTAN OHSU HTAN SRRS  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq                               Level1,Level2,Level3
# BulkWES                                   Level1,Level2,Level3
# ElectronMicroscopy                               Level1,Level2
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF                                  Level2,Level3
# Imaging - GeoMX-DSP
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC                                   Level2,Level3
# Imaging - t-CyCIF                         Level2,Level3,Level4
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA                                      Level2,Level3,Level4
# SRRSImaging                                                       Level2
# ScATAC-seq                                Level1,Level2,Level3    Level1
# ScRNA-seq                                                         Level1
# Slide-seq
#
# HTAN_Center                                      HTAN Stanford  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq                              Level1,Level2
# BulkRNA-seq                                      Level1,Level3
# BulkWES                                          Level1,Level2
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq                                  Level1,Level2,Level3
# Imaging                                                 Level1
# Imaging - CODEX                           Level2,Level3,Level4
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry                          Level1,Level3,Level4
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq                                Level1,Level2,Level3
# ScRNA-seq                                 Level1,Level2,Level3
# Slide-seq
#
# HTAN_Center                                     HTAN TNP - TMA  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF                           Level2,Level3,Level4
# Imaging - GeoMX-DSP                                     Level2
# Imaging - H&E
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC                            Level2,Level3,Level4
# Imaging - t-CyCIF                         Level2,Level3,Level4
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics         Level1,Level3
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq
# Slide-seq
#
# HTAN_Center                                   HTAN TNP SARDANA  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX                                         Level2
# Imaging - CyCIF                                         Level2
# Imaging - GeoMX-DSP
# Imaging - H&E                                           Level2
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER                                         Level2
# Imaging - mIHC                                          Level2
# Imaging - t-CyCIF                         Level2,Level3,Level4
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq
# Slide-seq
#
# HTAN_Center                                           HTAN Vanderbilt  \
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq   Level1,Level2,Level3,Level4
# BulkMethylation-seq
# BulkRNA-seq
# BulkWES                                          Level1,Level2,Level3
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                                  Level2
# Imaging - IMC
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF                                                 Level2
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq
#
# HTAN_Center                                                HTAN WUSTL
# Assay
# 10XGenomicsXeniumISSExperiment
# 10xVisiumSpatialTranscriptomics-RNA-seq   Level1,Level2,Level3,Level4
# BulkMethylation-seq
# BulkRNA-seq                                                    Level1
# BulkWES                                                        Level1
# ElectronMicroscopy
# ExSeqMinimal
# HI-C-seq
# Imaging
# Imaging - CODEX                                  Level2,Level3,Level4
# Imaging - CyCIF
# Imaging - GeoMX-DSP
# Imaging - H&E                                                  Level2
# Imaging - IMC                                                  Level2
# Imaging - MERFISH
# Imaging - MIBI
# Imaging - MxIF
# Imaging - RareCyte Orion
# Imaging - SABER
# Imaging - mIHC
# Imaging - t-CyCIF
# MassSpectrometry
# NanoStringGeoMxDSPSpatialTranscriptomics
# RPPA
# SRRSImaging
# ScATAC-seq                                Level1,Level2,Level3,Level4
# ScRNA-seq                                 Level1,Level2,Level3,Level4
# Slide-seq

# %% [markdown]
# ## 4.2 Number of files per center and assay type

# %% [markdown]
# This next table provides a long-form breakdown of the number of data files submitted by each HTAN center per assay type and level.

# %%
all_files = client.query("""
  SELECT Component, HTAN_Center, Count(*) AS Count
  FROM `isb-cgc-bq.HTAN.id_provenance_current`
  WHERE Component LIKE '%Level%'
  GROUP BY Component, HTAN_Center
  ORDER BY Component, HTAN_Center
  """).result().to_dataframe()

# %%
all_files.pivot_table(
    index='Component',
    columns='HTAN_Center',
    values='Count',
    fill_value=0).astype(int)
# Out:
# HTAN_Center                                     HTAN BU  HTAN CHOP  HTAN DFCI  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1         0          0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2         0          0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3         0          0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4         0          0          0
# BulkMethylation-seqLevel1                             0          0          0
# BulkMethylation-seqLevel2                             0          0          0
# BulkRNA-seqLevel1                                   826          0          0
# BulkRNA-seqLevel2                                   317          0          0
# BulkRNA-seqLevel3                                   186          0          0
# BulkWESLevel1                                       530        622          0
# BulkWESLevel2                                        24        392        194
# BulkWESLevel3                                        12        186          0
# ElectronMicroscopyLevel1                              0          0          0
# ElectronMicroscopyLevel2                              0          0          0
# HI-C-seqLevel1                                        0          0          0
# HI-C-seqLevel2                                        0          0          0
# HI-C-seqLevel3                                        0          0          0
# ImagingLevel1                                         0          0          0
# ImagingLevel2                                       358         15      16528
# ImagingLevel3Segmentation                             0         17          0
# ImagingLevel4                                         0         30          0
# MassSpectrometryLevel1                                0          0          0
# MassSpectrometryLevel3                                0          0          0
# MassSpectrometryLevel4                                0          0          0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1        0          0          0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3        0          0          0
# RPPALevel2                                            0          0          0
# RPPALevel3                                            0          0          0
# RPPALevel4                                            0          0          0
# SRRSImagingLevel2                                     0          0          0
# ScATAC-seqLevel1                                      0       1109          0
# ScATAC-seqLevel2                                      0        108          0
# ScATAC-seqLevel3                                      0        144          0
# ScATAC-seqLevel4                                      0       1053          0
# ScRNA-seqLevel1                                     506       1438        452
# ScRNA-seqLevel2                                      50       1131        432
# ScRNA-seqLevel3                                      45       1095         63
# ScRNA-seqLevel4                                      60       1597          0
# Slide-seqLevel1                                       0          0          0
# Slide-seqLevel2                                       0          0          0
# Slide-seqLevel3                                       0          0          0
#
# HTAN_Center                                     HTAN Duke  HTAN HMS  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1           0         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2           0         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3           0         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4           0         0
# BulkMethylation-seqLevel1                               0         0
# BulkMethylation-seqLevel2                               0         0
# BulkRNA-seqLevel1                                    1064       444
# BulkRNA-seqLevel2                                     953       444
# BulkRNA-seqLevel3                                    1727       222
# BulkWESLevel1                                        2630         0
# BulkWESLevel2                                         498         0
# BulkWESLevel3                                         236         0
# ElectronMicroscopyLevel1                                0         0
# ElectronMicroscopyLevel2                                0         0
# HI-C-seqLevel1                                          0         0
# HI-C-seqLevel2                                          0         0
# HI-C-seqLevel3                                          0         0
# ImagingLevel1                                           0         0
# ImagingLevel2                                        1075       558
# ImagingLevel3Segmentation                             395       145
# ImagingLevel4                                          79       144
# MassSpectrometryLevel1                                  0         0
# MassSpectrometryLevel3                                  0         0
# MassSpectrometryLevel4                                  0         0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1          0         0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3          0         0
# RPPALevel2                                              0         0
# RPPALevel3                                              0         0
# RPPALevel4                                              0         0
# SRRSImagingLevel2                                       0         0
# ScATAC-seqLevel1                                        0         0
# ScATAC-seqLevel2                                        0         0
# ScATAC-seqLevel3                                        0         0
# ScATAC-seqLevel4                                        0         0
# ScRNA-seqLevel1                                       322         0
# ScRNA-seqLevel2                                        30         0
# ScRNA-seqLevel3                                        90         0
# ScRNA-seqLevel4                                        22         0
# Slide-seqLevel1                                         0         0
# Slide-seqLevel2                                         0         0
# Slide-seqLevel3                                         0         0
#
# HTAN_Center                                     HTAN HTAPP  HTAN MSK  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1          400         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2          400         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3          336         0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4            0         0
# BulkMethylation-seqLevel1                                0         0
# BulkMethylation-seqLevel2                                0         0
# BulkRNA-seqLevel1                                        0         0
# BulkRNA-seqLevel2                                      154         0
# BulkRNA-seqLevel3                                        0         0
# BulkWESLevel1                                            0         0
# BulkWESLevel2                                          398         0
# BulkWESLevel3                                            0         0
# ElectronMicroscopyLevel1                                 0         0
# ElectronMicroscopyLevel2                                 0         0
# HI-C-seqLevel1                                           0         0
# HI-C-seqLevel2                                           0         0
# HI-C-seqLevel3                                           0         0
# ImagingLevel1                                            0         0
# ImagingLevel2                                         3374      1408
# ImagingLevel3Segmentation                             4205         0
# ImagingLevel4                                          291      1350
# MassSpectrometryLevel1                                   0         0
# MassSpectrometryLevel3                                   0         0
# MassSpectrometryLevel4                                   0         0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1           0         0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3           0         0
# RPPALevel2                                               0         0
# RPPALevel3                                               0         0
# RPPALevel4                                               0         0
# SRRSImagingLevel2                                        0         0
# ScATAC-seqLevel1                                         0         0
# ScATAC-seqLevel2                                         0         0
# ScATAC-seqLevel3                                         0         0
# ScATAC-seqLevel4                                         0         0
# ScRNA-seqLevel1                                       9228      1050
# ScRNA-seqLevel2                                       9228      1050
# ScRNA-seqLevel3                                      13653       625
# ScRNA-seqLevel4                                        948     61691
# Slide-seqLevel1                                         45         0
# Slide-seqLevel2                                        516         0
# Slide-seqLevel3                                       3612         0
#
# HTAN_Center                                     HTAN OHSU  HTAN SRRS  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1           0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2           0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3           0          0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4           0          0
# BulkMethylation-seqLevel1                               0          0
# BulkMethylation-seqLevel2                               0          0
# BulkRNA-seqLevel1                                      88          0
# BulkRNA-seqLevel2                                      56          0
# BulkRNA-seqLevel3                                      38          0
# BulkWESLevel1                                         336          0
# BulkWESLevel2                                         168          0
# BulkWESLevel3                                         109          0
# ElectronMicroscopyLevel1                            63887          0
# ElectronMicroscopyLevel2                            36958          0
# HI-C-seqLevel1                                          0          0
# HI-C-seqLevel2                                          0          0
# HI-C-seqLevel3                                          0          0
# ImagingLevel1                                           0          0
# ImagingLevel2                                         245          0
# ImagingLevel3Segmentation                             437          0
# ImagingLevel4                                         642          0
# MassSpectrometryLevel1                                  0          0
# MassSpectrometryLevel3                                  0          0
# MassSpectrometryLevel4                                  0          0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1          0          0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3          0          0
# RPPALevel2                                             26          0
# RPPALevel3                                             26          0
# RPPALevel4                                             26          0
# SRRSImagingLevel2                                       0        143
# ScATAC-seqLevel1                                       66         56
# ScATAC-seqLevel2                                       66          0
# ScATAC-seqLevel3                                       38          0
# ScATAC-seqLevel4                                        0          0
# ScRNA-seqLevel1                                         0         63
# ScRNA-seqLevel2                                         0          0
# ScRNA-seqLevel3                                         0          0
# ScRNA-seqLevel4                                         0          0
# Slide-seqLevel1                                         0          0
# Slide-seqLevel2                                         0          0
# Slide-seqLevel3                                         0          0
#
# HTAN_Center                                     HTAN Stanford  HTAN TNP - TMA  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1               0               0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2               0               0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3               0               0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4               0               0
# BulkMethylation-seqLevel1                                  80               0
# BulkMethylation-seqLevel2                                  80               0
# BulkRNA-seqLevel1                                         420               0
# BulkRNA-seqLevel2                                           0               0
# BulkRNA-seqLevel3                                          72               0
# BulkWESLevel1                                             632               0
# BulkWESLevel2                                             630               0
# BulkWESLevel3                                               0               0
# ElectronMicroscopyLevel1                                    0               0
# ElectronMicroscopyLevel2                                    0               0
# HI-C-seqLevel1                                             66               0
# HI-C-seqLevel2                                             66               0
# HI-C-seqLevel3                                             66               0
# ImagingLevel1                                              16               0
# ImagingLevel2                                              71            1569
# ImagingLevel3Segmentation                                1598            1543
# ImagingLevel4                                            1622            1193
# MassSpectrometryLevel1                                  57087               0
# MassSpectrometryLevel3                                  31248               0
# MassSpectrometryLevel4                                  31248               0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1              0             665
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3              0             654
# RPPALevel2                                                  0               0
# RPPALevel3                                                  0               0
# RPPALevel4                                                  0               0
# SRRSImagingLevel2                                           0               0
# ScATAC-seqLevel1                                          640               0
# ScATAC-seqLevel2                                          136               0
# ScATAC-seqLevel3                                          640               0
# ScATAC-seqLevel4                                            0               0
# ScRNA-seqLevel1                                           384               0
# ScRNA-seqLevel2                                           384               0
# ScRNA-seqLevel3                                           192               0
# ScRNA-seqLevel4                                             0               0
# Slide-seqLevel1                                             0               0
# Slide-seqLevel2                                             0               0
# Slide-seqLevel3                                             0               0
#
# HTAN_Center                                     HTAN TNP SARDANA  \
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1                  0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2                  0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3                  0
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4                  0
# BulkMethylation-seqLevel1                                      0
# BulkMethylation-seqLevel2                                      0
# BulkRNA-seqLevel1                                              0
# BulkRNA-seqLevel2                                              0
# BulkRNA-seqLevel3                                              0
# BulkWESLevel1                                                  0
# BulkWESLevel2                                                  0
# BulkWESLevel3                                                  0
# ElectronMicroscopyLevel1                                       0
# ElectronMicroscopyLevel2                                       0
# HI-C-seqLevel1                                                 0
# HI-C-seqLevel2                                                 0
# HI-C-seqLevel3                                                 0
# ImagingLevel1                                                  0
# ImagingLevel2                                                251
# ImagingLevel3Segmentation                                     25
# ImagingLevel4                                                 25
# MassSpectrometryLevel1                                         0
# MassSpectrometryLevel3                                         0
# MassSpectrometryLevel4                                         0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1                 0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3                 0
# RPPALevel2                                                     0
# RPPALevel3                                                     0
# RPPALevel4                                                     0
# SRRSImagingLevel2                                              0
# ScATAC-seqLevel1                                               0
# ScATAC-seqLevel2                                               0
# ScATAC-seqLevel3                                               0
# ScATAC-seqLevel4                                               0
# ScRNA-seqLevel1                                                0
# ScRNA-seqLevel2                                                0
# ScRNA-seqLevel3                                                0
# ScRNA-seqLevel4                                                0
# Slide-seqLevel1                                                0
# Slide-seqLevel2                                                0
# Slide-seqLevel3                                                0
#
# HTAN_Center                                     HTAN Vanderbilt  HTAN WUSTL
# Component
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel1               104         304
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel2               104         304
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel3               216        1250
# 10xVisiumSpatialTranscriptomics-RNA-seqLevel4               200         792
# BulkMethylation-seqLevel1                                     0           0
# BulkMethylation-seqLevel2                                     0           0
# BulkRNA-seqLevel1                                             0         434
# BulkRNA-seqLevel2                                             0           0
# BulkRNA-seqLevel3                                             0           0
# BulkWESLevel1                                               702        1058
# BulkWESLevel2                                               702           0
# BulkWESLevel3                                               233           0
# ElectronMicroscopyLevel1                                      0           0
# ElectronMicroscopyLevel2                                      0           0
# HI-C-seqLevel1                                                0           0
# HI-C-seqLevel2                                                0           0
# HI-C-seqLevel3                                                0           0
# ImagingLevel1                                                 0           0
# ImagingLevel2                                               123         212
# ImagingLevel3Segmentation                                     0           4
# ImagingLevel4                                                 0           8
# MassSpectrometryLevel1                                        0           0
# MassSpectrometryLevel3                                        0           0
# MassSpectrometryLevel4                                        0           0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel1                0           0
# NanoStringGeoMxDSPSpatialTranscriptomicsLevel3                0           0
# RPPALevel2                                                    0           0
# RPPALevel3                                                    0           0
# RPPALevel4                                                    0           0
# SRRSImagingLevel2                                             0           0
# ScATAC-seqLevel1                                              0         677
# ScATAC-seqLevel2                                              0         684
# ScATAC-seqLevel3                                              0        1312
# ScATAC-seqLevel4                                              0         836
# ScRNA-seqLevel1                                             548        1005
# ScRNA-seqLevel2                                             580         813
# ScRNA-seqLevel3                                             484         537
# ScRNA-seqLevel4                                             637         726
# Slide-seqLevel1                                               0           0
# Slide-seqLevel2                                               0           0
# Slide-seqLevel3                                               0           0

# %% [markdown]
# ## 4.3 Total Cell Counts in Google BigQuery
# In this section, we aim to retrieve the total cell counts across HTAN genomic and spatial assay data tables in Google BigQuery. Given the varying formats of assay tables, we adopt different approaches to gather cell count information, distinguishing between narrow and non-narrow formats.

# %%
# obtain assay tables containing concatenated data derived from CSVs
full = client.query("""
  SELECT table_name
  FROM `isb-cgc-bq.HTAN`.INFORMATION_SCHEMA.TABLES
  WHERE (table_name LIKE 'imaging_level4%' AND table_name NOT LIKE '%metadata%')
  OR table_name = 'scRNAseq_HTAPP_level4_current'
  ORDER BY table_name
""").result().to_dataframe()

# obtain assay tables derived from h5ads
narrow = client.query("""
  SELECT table_name
  FROM `isb-cgc-bq.HTAN`.INFORMATION_SCHEMA.TABLES
  WHERE (table_name LIKE 'scRNAseq%' AND table_name NOT LIKE '%metadata%')
  AND (table_name NOT LIKE 'scRNAseq_VUMC%' OR table_name LIKE '%cellxgene%')
  AND table_name NOT LIKE 'scRNAseq_HTAPP_level4_%'
  ORDER BY table_name
""").result().to_dataframe()

# %%
def row_count(table):
  '''
  For csv/tsv derived tables, we can count one cell per row
  '''
  count = client.query(f"SELECT COUNT(*) AS count FROM `isb-cgc-bq.HTAN.{table}`")
  result = count.result()
  for row in result:
      return row['count']

# %%
def obs_count(table):
  '''
  Tables that were derived from h5ads have been converted into narrow format using
  obs & var indices. We can obtain cell count by selecting the max obs index
  '''
  count = client.query(f"SELECT MAX(iObs) AS count FROM `isb-cgc-bq.HTAN.{table}`")
  result = count.result()
  for row in result:
      return row['count']

# %%
cell_count = 0
for t in list(full['table_name']):
  cell_count = cell_count + row_count(t)
for t in list(narrow['table_name']):
  cell_count = cell_count + obs_count(t)

# %% [markdown]
# The total cell count in Google BigQuery (genomic and spatial data) is around 206 million cells

# %%
cell_count
# Out:
# 205554213

# %% [markdown]
# # 5. Specific modes of access and identification

# %% [markdown]
# ## 5.1 Identifying data by HTAN Data Release
#
# Here we demonstrate how users can filter files based on a specific HTAN Data Release, such as `Release 6.0`. We accomplish this by again utilizing the ID Provenance table, which contains information on all HTAN data files.

# %%
id_prov = client.query("""
  SELECT Component, Data_Release, HTAN_Center, Count(*) AS Count
  FROM `isb-cgc-bq.HTAN_versioned.id_provenance_r6`
  WHERE Data_Release = 'Release 6.0'
  GROUP BY Component, Data_Release, HTAN_Center
""").result().to_dataframe()
id_prov
# Out:
#                                          Component Data_Release  \
# 0                                BulkRNA-seqLevel2  Release 6.0
# 1                                BulkRNA-seqLevel3  Release 6.0
# 2                                    ImagingLevel2  Release 6.0
# 3                                  ScRNA-seqLevel3  Release 6.0
# 4                                  ScRNA-seqLevel1  Release 6.0
# 5                                    BulkWESLevel2  Release 6.0
# 6                        ImagingLevel3Segmentation  Release 6.0
# 7                                    ImagingLevel2  Release 6.0
# 8                                    ImagingLevel4  Release 6.0
# 9                                 ScATAC-seqLevel1  Release 6.0
# 10                                ScATAC-seqLevel2  Release 6.0
# 11                                ScATAC-seqLevel3  Release 6.0
# 12                                ScATAC-seqLevel1  Release 6.0
# 13                                 ScRNA-seqLevel1  Release 6.0
# 14                                 Slide-seqLevel1  Release 6.0
# 15                                 Slide-seqLevel2  Release 6.0
# 16                                 Slide-seqLevel3  Release 6.0
# 17                                 ScRNA-seqLevel4  Release 6.0
# 18                                    ExSeqMinimal  Release 6.0
# 19                                   ImagingLevel2  Release 6.0
# 20  10xVisiumSpatialTranscriptomics-AuxiliaryFiles  Release 6.0
# 21   10xVisiumSpatialTranscriptomics-RNA-seqLevel4  Release 6.0
# 22                                 ScRNA-seqLevel1  Release 6.0
# 23                                 ScRNA-seqLevel2  Release 6.0
# 24                                 ScRNA-seqLevel3  Release 6.0
# 25                                 ScRNA-seqLevel4  Release 6.0
# 26  10xVisiumSpatialTranscriptomics-AuxiliaryFiles  Release 6.0
# 27   10xVisiumSpatialTranscriptomics-RNA-seqLevel1  Release 6.0
# 28   10xVisiumSpatialTranscriptomics-RNA-seqLevel2  Release 6.0
# 29   10xVisiumSpatialTranscriptomics-RNA-seqLevel3  Release 6.0
# 30                                   BulkWESLevel1  Release 6.0
# 31                                   ImagingLevel2  Release 6.0
# 32                                ScATAC-seqLevel1  Release 6.0
# 33                               BulkRNA-seqLevel1  Release 6.0
# 34                                ScATAC-seqLevel3  Release 6.0
# 35                               BulkRNA-seqLevel1  Release 6.0
# 36                               BulkRNA-seqLevel3  Release 6.0
# 37                                   ImagingLevel2  Release 6.0
# 38                       ImagingLevel3Segmentation  Release 6.0
# 39                                   ImagingLevel4  Release 6.0
# 40                                   ImagingLevel2  Release 6.0
# 41                                   ImagingLevel4  Release 6.0
# 42  NanoStringGeoMxDSPSpatialTranscriptomicsLevel1  Release 6.0
# 43  NanoStringGeoMxDSPSpatialTranscriptomicsLevel3  Release 6.0
#
#        HTAN_Center  Count
# 0          HTAN BU    317
# 1          HTAN BU    186
# 2        HTAN DFCI  16528
# 3        HTAN DFCI     63
# 4        HTAN DFCI     20
# 5        HTAN DFCI      8
# 6        HTAN OHSU    437
# 7        HTAN OHSU     67
# 8        HTAN OHSU    402
# 9        HTAN OHSU     28
# 10       HTAN OHSU     28
# 11       HTAN OHSU     14
# 12       HTAN SRRS     56
# 13       HTAN SRRS     63
# 14      HTAN HTAPP     45
# 15      HTAN HTAPP    516
# 16      HTAN HTAPP   3612
# 17      HTAN HTAPP      3
# 18      HTAN HTAPP  21153
# 19      HTAN HTAPP   1203
# 20      HTAN HTAPP     60
# 21      HTAN WUSTL    792
# 22      HTAN WUSTL    144
# 23      HTAN WUSTL     33
# 24      HTAN WUSTL     45
# 25      HTAN WUSTL     45
# 26      HTAN WUSTL     82
# 27      HTAN WUSTL    204
# 28      HTAN WUSTL    204
# 29      HTAN WUSTL    984
# 30      HTAN WUSTL    288
# 31      HTAN WUSTL     12
# 32      HTAN WUSTL     12
# 33      HTAN WUSTL     76
# 34   HTAN Stanford      8
# 35   HTAN Stanford     72
# 36   HTAN Stanford     72
# 37   HTAN Stanford     32
# 38   HTAN Stanford    206
# 39   HTAN Stanford    206
# 40  HTAN TNP - TMA    276
# 41  HTAN TNP - TMA    665
# 42  HTAN TNP - TMA    665
# 43  HTAN TNP - TMA    654

# %% [markdown]
# ## 5.2 Identifying Data in the NIH General Commons (GC)
#
# Similarly, we can identify data released on the GC using the `isb-cgc-bq.HTAN.gc_drs_map_current` BigQuery table. This table lists all ~60,000 data files available in the GC as of the most current HTAN Data Release (the DCC submits data to the GC following each major data release).

# %%
gc = client.query("""
SELECT * FROM `isb-cgc-bq.HTAN.gc_drs_map_current`
""").result().to_dataframe()

gc
# Out:
#                                                     name     entityId  \
# 0              1-PCGA02-20005-1005102_S1_R1_001.fastq.gz  syn53283905
# 1              1-PCGA02-20005-1005102_S1_R1_001.fastq.gz  syn53283905
# 2              1-PCGA02-20005-1005102_S1_R2_001.fastq.gz  syn53283874
# 3              1-PCGA02-20005-1005102_S1_R2_001.fastq.gz  syn53283874
# 4            10-PCGA02-20152-1000048_S10_R1_001.fastq.gz  syn53283759
# ...                                                  ...          ...
# 65779  ht565b1_s1h2a3y1e1.GCTTGAGACG-ACGCAAGAAG.HH5NV...  syn61464414
# 65780  ht565b1_s1h2a3y1e1.GCTTGAGACG-ACGCAAGAAG.HH5NV...  syn61464333
# 65781              mCRC_S16-32775_Met__20230826.ome.tiff  syn61463092
# 65782              mCRC_S16-38794_Met__20230823.ome.tiff  syn61464203
# 65783          mCRC_S16-38794_Primary__20230824.ome.tiff  syn61464377
#
#         HTAN_Data_File_ID                                       drs_uri  \
# 0      HTA3_70005_3600639  dg.4DFC/20852dd0-9085-11ef-b71c-3f2710856ceb
# 1      HTA3_70005_3600639  dg.4DFC/70d84a82-03d2-11ef-a132-7f12e8801d7c
# 2      HTA3_70005_3221388  dg.4DFC/20a8a8be-9085-11ef-a3a5-3f109c193228
# 3      HTA3_70005_3221388  dg.4DFC/70e79a14-03d2-11ef-9811-d7ff64fafaf4
# 4      HTA3_70152_0185853  dg.4DFC/70e0e002-03d2-11ef-9751-8fbe5ca478f7
# ...                   ...                                           ...
# 65779      HTA12_255_1008  dg.4DFC/1e0c2220-9085-11ef-bdff-8f6d3dd0a631
# 65780      HTA12_255_1009  dg.4DFC/1e1bb230-9085-11ef-8243-83a15db66a4e
# 65781      HTA12_279_2002  dg.4DFC/7E491980-65C8-4D2F-BAA7-A992C9B2617E
# 65782      HTA12_280_2004  dg.4DFC/EECF1505-68B7-4416-857E-0BB9207C9F74
# 65783      HTA12_280_2003  dg.4DFC/01DF543A-DDE8-4D9D-BE68-17BB65C39505
#
#       HTAN_Center
# 0         HTAN BU
# 1         HTAN BU
# 2         HTAN BU
# 3         HTAN BU
# 4         HTAN BU
# ...           ...
# 65779  HTAN WUSTL
# 65780  HTAN WUSTL
# 65781  HTAN WUSTL
# 65782  HTAN WUSTL
# 65783  HTAN WUSTL
#
# [65784 rows x 5 columns]

# %% [markdown]
# ## 5.3 Identifying Assay Data in ISB-CGC BigQuery
#
# The HTAN Data Coordinating Center (DCC) has now made over 1000 data files available in ISB-CGC BigQuery, including tabular assay data and channel metadata files.
#
# These files are structured in two main formats: in some instances, each data file corresponds directly to a BigQuery table, while in others, files within a dataset are combined into a single BigQuery table.
#
# The `isb-cgc-bq.HTAN.dataFileSynapseID_to_BigQueryTableID_map_current` table can be utilized to identify the presence of data files in Google BigQuery using their Synapse IDs, and determine the tables they are associated with.

# %%
syn_bq_map = client.query("""
SELECT * FROM `isb-cgc-bq.HTAN.dataFileSynapseID_to_BigQueryTableID_map_current`
""").result().to_dataframe()

syn_bq_map
# Out:
#          entityId                                       bq_table_id
# 0     syn26535445       isb-cgc-bq.HTAN.imaging_level4_OHSU_current
# 1     syn53275842       isb-cgc-bq.HTAN.imaging_level4_OHSU_current
# 2     syn53275838       isb-cgc-bq.HTAN.imaging_level4_OHSU_current
# 3     syn26535453       isb-cgc-bq.HTAN.imaging_level4_OHSU_current
# 4     syn31547329       isb-cgc-bq.HTAN.imaging_level4_OHSU_current
# ...           ...                                               ...
# 1364  syn26486784  isb-cgc-bq.HTAN.imaging_channel_metadata_current
# 1365  syn26486786  isb-cgc-bq.HTAN.imaging_channel_metadata_current
# 1366  syn26486788  isb-cgc-bq.HTAN.imaging_channel_metadata_current
# 1367  syn26486790  isb-cgc-bq.HTAN.imaging_channel_metadata_current
# 1368  syn26486792  isb-cgc-bq.HTAN.imaging_channel_metadata_current
#
# [1369 rows x 2 columns]

# %% [markdown]
# A breakdown of the number of data files contained in each BigQuery assay table

# %%
syn_bq_map.bq_table_id.value_counts()
# Out:
# bq_table_id
# isb-cgc-bq.HTAN.imaging_channel_metadata_current                                                   475
# isb-cgc-bq.HTAN.imaging_level4_TNP_TMA_phase1_current                                              352
# isb-cgc-bq.HTAN.imaging_level4_TNP_TMA_phase3_current                                              176
# isb-cgc-bq.HTAN.imaging_level4_OHSU_current                                                        120
# isb-cgc-bq.HTAN.imaging_level4_HMS_orion_current                                                    75
# isb-cgc-bq.HTAN.scRNAseq_HTAPP_level4_current                                                       47
# isb-cgc-bq.HTAN.imaging_level4_HMS_crc_mask_current                                                 40
# isb-cgc-bq.HTAN.imaging_level4_HMS_crc_current                                                      32
# isb-cgc-bq.HTAN.imaging_level4_HMS_mel_mask_current                                                 20
# isb-cgc-bq.HTAN.imaging_level4_HTAPP_merfish_current                                                12
# isb-cgc-bq.HTAN.imaging_level4_HMS_mel_current                                                       2
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_tcell_current                                                      1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_Mesenchymal_cells_current                                          1
# isb-cgc-bq.HTAN.seurat_scATAC_patient_clean_current                                                  1
# isb-cgc-bq.HTAN.scRNAseq_CHOP_seurat_pool_logNorm_gini_FiveHD_10Xv3_downsample10000HSPC_current      1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_RU1215_epithelial_cells_current                                    1
# isb-cgc-bq.HTAN.scRNAseq_MSK_Myeloid_SCLC_samples_only_current                                       1
# isb-cgc-bq.HTAN.scRNAseq_VUMC_VAL_DIS_NOEPI_cellxgene_current                                        1
# isb-cgc-bq.HTAN.scRNAseq_VUMC_HTAN_VAL_EPI_cellxgene_current                                         1
# isb-cgc-bq.HTAN.scRNAseq_VUMC_HTAN_DIS_EPI_cellxgene_current                                         1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_myeloid_cells_current                                              1
# isb-cgc-bq.HTAN.scRNAseq_MSK_NSCLC_epithelial_cells_current                                          1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_epithelial_cells_current                                           1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_combined_samples_current                                           1
# isb-cgc-bq.HTAN.imaging_level4_Duke_mibi_current                                                     1
# isb-cgc-bq.HTAN.scRNAseq_VUMC_ABNORMALS_EPI_V2_current                                               1
# isb-cgc-bq.HTAN.scRNAseq_MSK_epithelial_cells_current                                                1
# isb-cgc-bq.HTAN.scRNAseq_MSK_immune_cells_current                                                    1
# isb-cgc-bq.HTAN.scRNAseq_MSK_SCLC_immune_cells_current                                               1
# Name: count, dtype: int64

# %% [markdown]
# # 6. Relevant Citations and Links

# %% [markdown]
# [HTAN Portal](https://humantumoratlas.org/)
#
# [Overview paper, Cell, April 2020](https://www.sciencedirect.com/science/article/pii/S0092867420303469)
